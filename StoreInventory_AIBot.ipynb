# %% [markdown]
# <a href="https://colab.research.google.com/github/snehasmc/StoreInventoryAIBot/blob/main/StoreInventory_AIBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install embedchain

# %%
# !pip install embedchain[huggingface-hub] embedchain[opensource]

# %%
import os #operating system=> store the key in environment variables
from embedchain import App
from getpass import getpass #optional

# %%
hf_token = getpass("Enter your HF Access token")
os.environ["HUGGINGFACE_ACCESS_TOKEN"] = hf_token
# Out:
# Enter your HF Access token··········

# %%
# create config.yaml file.
config = """
llm:
  provider: huggingface
  config:
    model: 'google/flan-t5-xxl'
    temperature: 0.5
    max_tokens: 1000
    top_p: 0.8
    stream: false

embedder:
  provider: huggingface
  config:
    model: 'sentence-transformers/all-mpnet-base-v2'
"""

# Write the multi-line string to a YAML file
with open('huggingface.yaml', 'w') as file:
    file.write(config)

# %%
#app = App()- approach OpenAI
app = App.from_config(yaml_path="huggingface.yaml")

# %%
import pandas as pd

data = pd.read_csv("data.csv")
data.sample(40)
# Out:
#     product_id                                              model  \
# 35         125                           Whitening Deodorant Roll
# 22          82                Lakmé Absolute Blur Perfect Makeup
# 26         136                                   Lakmé  Day Creme
# 6           58                                          pineapple
# 45         134               Eyelash &amp;Pure Eyebrow Growth Oil
# 28         114  Almond, Apricot &amp; Grape oil Shave Oil  (50...
# 11          71              BKDT Marketing Silicone Massager Bath
# 37         126                           Whitening Deodorant Roll
# 31         123                            GARNIER Naturals Creme
# 33         120                         GILLETTE SENSITIVE COOL  (
# 2           68                      Engage M1 Perfume Body Spray
# 0           69                                ENVY Combo Perfume
# 10          55                                              apple
# ...

# %%
prompt = input("Enter your prompt: ")

results = []

for index, row in data.iterrows():
    model_name = row['model']
    quantity = row['quantity']

    if f"show me list of models with quantity {quantity}" in prompt.lower():
        template = f"""You are a Store Inventory bot, you only answer relevant to the context
        ..
        .
        .
        .
        PROMPT: {prompt}"""
        response = app.query(template)
        results.append((model_name, response))

if results:
    print("Results based on your prompt:")
    for model, response in results:
        print(f"Model: {model}\nResponse: {response}\n")
else:
    print("No results found for the given prompt.")
# Out:
# Enter your prompt: show me list of models with quantity 1000
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:127: FutureWarning: '__init__' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '0.19.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)
# Results based on your prompt:
# Model: ENVY Combo Perfume
# Response: I found one model with 1000 quantity. It is model 124.
#
# Model: FOGG Master Intense
# Response: I found one model with 1000 quantity. It is model 124.
#
# Model: Engage M1 Perfume Body Spray
# Response: I found one model with 1000 quantity. It is model 124.
#
# Model: Onion
# Response: I found one model with 1000 quantity. It is model 124.
#
# ...

# %%
pip install gradio
# Out:
# ...
# ERROR: Operation cancelled by user

# %%
# !pip install gradio

# %%
import gradio as gr

# %%
with gr.Blocks() as demo:
    chatbot = gr.Chatbot() # user inferface
    msg = gr.Textbox() # this will create a entry box to the user to enter the prompt
    clear = gr.ClearButton([msg, chatbot]) #clear the text from entry box

    def predict(message, chat_history):
      response = app.query(message)
      chat_history.append((message, response))
      return "", chat_history


    msg.submit(predict, [msg, chatbot], [msg, chatbot])

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://e8a03f442857a76fd7.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e8a03f442857a76fd7.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
